# %%
print("ok")
# Out:
# ok

# %% [markdown]
# # Test model connectivity

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI

# %%
# Create embedding object with model name and optional API key  //models/text-embedding-004//gemini-embedding-001
embeddings = GoogleGenerativeAIEmbeddings(model="models/text-embedding-004", google_api_key="AIzaSyDO31oE4xQ8c3EnU76BpCYpXRT07sNRY2Q")

# Generate embedding for a query
embedding_vector = embeddings.embed_query("What's our Q1 revenue?")

# %%
embedding_vector
# Out:
# [0.022226594388484955,
#  -0.005298603791743517,
#  -0.03638031706213951,
#  -0.022343235090374947,
#  0.021077357232570648,
#  0.026357078924775124,
#  -0.005140196997672319,
#  -0.0047151208855211735,
#  -0.020215705037117004,
#  0.004603210836648941,
#  0.021817319095134735,
#  0.009138683788478374,
#  0.10358211398124695,
#  -0.005005174316465855,
#  0.01096127089112997,
#  -0.01904454454779625,
#  0.005782195366919041,
#  -0.015201744623482227,
#  -0.13191628456115723,
#  -0.0029817058239132166,
#  0.01769891194999218,
#  -0.010750621557235718,
#  0.0003200707142241299,
#  -0.0002848370058927685,
#  -0.029578616842627525,
#  -0.031128263100981712,
#  -0.02592356875538826,
#  -0.0026727376971393824,
#  -0.014347424730658531,
#  -0.013856600970029831,
#  0.04075340926647186,
#  0.0566372312605381,
#  -0.025405442342162132,
#  -0.07057256251573563,
#  -0.013354412280023098,
#  0.01110386848449707,
#  -0.017656734213232994,
#  0.049004241824150085,
#  0.05370621383190155,
# ...

# %% [markdown]
# # Dcode the embedding from vector DB

# %%
b64="..."

# %%
import base64
import numpy as np

decoded = base64.b64decode(b64)
vector = np.frombuffer(decoded, dtype=np.float32)
print(vector.tolist())
# Out:
# [-2.5410766924439402e+29, 21229.8671875, 3.0986863615908736e-37, 7.183100655201946e+33, -1.4862832236406947e+25, 1.892819235895266e+30, 3.8256309823055282e-34, 239.17669677734375, -7.470593551799676e-23, 8.883568105729556e+17, 674958069989376.0, -8.933857885244645e-13, -3.1067939887385876e-10, 1.5048551725837036e-30, -676662607872.0, 2.4002936156306063e-27, -54434032.0, -3211215.0, -4.054133569297846e-06, -3.8583347627962894e-10, 0.08852813392877579, -3.4555251097652768e-37, -2.287785388138173e+28, -1.262329072007466e-15, 1074727223296.0, -4.1932053565979, -2.5771869331947528e-06, 1.9586646702585534e-32, 7.693211055756033e+34, 1.0929849842216863e-27, -16452157.0, -8.668642264938037e-27, 2.3481491586337997e+17, -4.201910404261085e+18, -32320638976.0, -121.59908294677734, 7891870.0, 6.517913432543968e-25, -2.2062816948855967e+35, 6.199438668633035e+37, 3.054758151247184e+28, -6.856360101892278e-08, -976.925537109375, -7.952765531909933e-23, -28837.86328125, 1.2007829354843125e-05, -2.1
# ...

# %%
# !pip install google-generativeai

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyDO31oE4xQ8c3EnU76BpCYpXRT07sNRY2Q")

model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("What is the capital of France?")
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import google.generativeai as genai
#       3 genai.configure(api_key="AIzaSyDO31oE4xQ8c3EnU76BpCYpXRT07sNRY2Q")
#       5 model = genai.GenerativeModel('gemini-pro')
#
# ModuleNotFoundError: No module named 'google.generativeai'
